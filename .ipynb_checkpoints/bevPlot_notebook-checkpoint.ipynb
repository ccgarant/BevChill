# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()
# %matplotlib inline

# %%
cd TestResults/
# Out:
# /Users/christophegarant/Documents/GitHub/BevChill/TestResults

# %%
ls
# Out:
# Perroni_20190716.csv                  Water_in_Perroni_Bottle_20190716.csv

# %%
data_file_csv = 'Perroni_20190716'

# %%
str(data_file_csv)
if ".csv" not in data_file_csv:
    print('add .csv extension')
# Out:
# add .csv extension

# %%
def bevPlot(data_file_csv):
    str(data_file_csv)
    if ".csv" not in data_file_csv:
        print('add .csv extension')
    p = pd.read_csv(data_file_csv, names=['datetime','elapsed time','T deg C','T deg F'])
    p.plot(x='elapsed time',y='T deg C',figsize=(15,10),lw=4,title='Bev Chill Plot')

# %%
bevPlot('Perroni_20190716.csv')
